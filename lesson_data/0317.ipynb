# 2017-04-14   8043  1940.0  4.145876
# 2017-04-15   7435  2300.0  3.232609
# 2017-04-16   7529  2300.0  3.273478
# 2017-04-17   8031  1940.0  4.139691
# 2017-04-18   8475  2300.0  3.684783
# 2017-04-19   8132  1950.0  4.170256
# 2017-04-20  15328  1800.0  8.515556
# 2017-04-21  12849  1940.0  6.623196
# 2017-04-22   4029  2300.0  1.751739
# 2017-04-23   3890  1950.0  1.994872
# 2017-04-24   8093  1850.0  4.374595
# 2017-04-25   7823  1950.0  4.011795
# ...

# %%
def exercise_judge(ex):
    if ex <= 3.0:
        return 'Low'
    elif 3 < ex <= 6.0:
        return 'Mid'
    else:
        return 'High'

# %%
df.loc[:, '運動指数'] = df.loc[:, '歩数/カロリー'].apply(exercise_judge)
df
# Out:
#                歩数  摂取カロリー   歩数/カロリー  運動指数
# date
# 2017-04-01   5439  2500.0  2.175600   Low
# 2017-04-02   2510  2300.0  1.091304   Low
# 2017-04-03  10238  1950.0  5.250256   Mid
# 2017-04-04   8209  1850.0  4.437297   Mid
# 2017-04-05   9434  1930.0  4.888083   Mid
# 2017-04-06   7593  1800.0  4.218333   Mid
# 2017-04-07   9320  1940.0  4.804124   Mid
# 2017-04-08   4873  2300.0  2.118696   Low
# 2017-04-09  12045  1950.0  6.176923  High
# 2017-04-10   7493  1850.0  4.050270   Mid
# 2017-04-11   7289  1930.0  3.776684   Mid
# 2017-04-12   6481  2300.0  2.817826   Low
# 2017-04-13  10287  1800.0  5.715000   Mid
# 2017-04-14   8043  1940.0  4.145876   Mid
# 2017-04-15   7435  2300.0  3.232609   Mid
# 2017-04-16   7529  2300.0  3.273478   Mid
# 2017-04-17   8031  1940.0  4.139691   Mid
# 2017-04-18   8475  2300.0  3.684783   Mid
# 2017-04-19   8132  1950.0  4.170256   Mid
# 2017-04-20  15328  1800.0  8.515556  High
# 2017-04-21  12849  1940.0  6.623196  High
# ...

# %%
 df.to_pickle('lesson_20200317health.pickle')

# %%
df_moved = pd.get_dummies(df.loc[:, '運動指数'], prefix='運動')
df_moved
# Out:
#             運動_High  運動_Low  運動_Mid
# date
# 2017-04-01        0       1       0
# 2017-04-02        0       1       0
# 2017-04-03        0       0       1
# 2017-04-04        0       0       1
# 2017-04-05        0       0       1
# 2017-04-06        0       0       1
# 2017-04-07        0       0       1
# 2017-04-08        0       1       0
# 2017-04-09        1       0       0
# 2017-04-10        0       0       1
# 2017-04-11        0       0       1
# 2017-04-12        0       1       0
# 2017-04-13        0       0       1
# 2017-04-14        0       0       1
# 2017-04-15        0       0       1
# 2017-04-16        0       0       1
# 2017-04-17        0       0       1
# 2017-04-18        0       0       1
# 2017-04-19        0       0       1
# 2017-04-20        1       0       0
# 2017-04-21        1       0       0
# 2017-04-22        0       1       0
# 2017-04-23        0       1       0
# 2017-04-24        0       0       1
# 2017-04-25        0       0       1
# ...

# %%
df_moved.to_pickle('test_20200317moved.pickle')

# %%
dates = pd.date_range(start='2020-01-01', end='2020-01-31')
dates
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10', '2020-01-11', '2020-01-12',
#                '2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16',
#                '2020-01-17', '2020-01-18', '2020-01-19', '2020-01-20',
#                '2020-01-21', '2020-01-22', '2020-01-23', '2020-01-24',
#                '2020-01-25', '2020-01-26', '2020-01-27', '2020-01-28',
#                '2020-01-29', '2020-01-30', '2020-01-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randint(1,32,31),index=dates, columns=['hoge'])

# %%
df
# Out:
#             hoge
# 2020-01-01     2
# 2020-01-02    18
# 2020-01-03     4
# 2020-01-04    15
# 2020-01-05    10
# 2020-01-06    10
# 2020-01-07     4
# 2020-01-08    21
# 2020-01-09    13
# 2020-01-10    23
# 2020-01-11    21
# 2020-01-12     9
# 2020-01-13    30
# 2020-01-14    25
# 2020-01-15    26
# 2020-01-16    19
# 2020-01-17     9
# 2020-01-18     8
# 2020-01-19    30
# 2020-01-20    31
# 2020-01-21    14
# 2020-01-22    30
# 2020-01-23    27
# 2020-01-24    21
# 2020-01-25    21
# 2020-01-26    27
# 2020-01-27    22
# 2020-01-28    14
# 2020-01-29    24
# 2020-01-30     8
# 2020-01-31    17

# %%
dates = pd.date_range(start='2019-01-01', periods=365)
dates
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10',
#                ...
#                '2019-12-22', '2019-12-23', '2019-12-24', '2019-12-25',
#                '2019-12-26', '2019-12-27', '2019-12-28', '2019-12-29',
#                '2019-12-30', '2019-12-31'],
#               dtype='datetime64[ns]', length=365, freq='D')

# %%
df = pd.DataFrame(np.random.randint(1, 32, 365), index=dates, columns=['hoge'])
df
# Out:
#             hoge
# 2019-01-01    29
# 2019-01-02    21
# 2019-01-03    28
# 2019-01-04    22
# 2019-01-05    11
# 2019-01-06    16
# 2019-01-07    13
# 2019-01-08     8
# 2019-01-09     1
# 2019-01-10    20
# 2019-01-11     1
# 2019-01-12    16
# 2019-01-13    27
# 2019-01-14    14
# 2019-01-15    15
# 2019-01-16    29
# 2019-01-17    17
# 2019-01-18    31
# 2019-01-19    14
# 2019-01-20    17
# 2019-01-21     3
# 2019-01-22    16
# 2019-01-23    30
# 2019-01-24    22
# 2019-01-25    18
# 2019-01-26     3
# 2019-01-27     3
# 2019-01-28     1
# 2019-01-29    23
# 2019-01-30    13
# ...          ...
# 2019-12-02     8
# 2019-12-03     9
# 2019-12-04    27
# 2019-12-05    15
# 2019-12-06    14
# 2019-12-07    11
# 2019-12-08     7
# 2019-12-09    31
# 2019-12-10     4
# 2019-12-11     4
# 2019-12-12    22
# 2019-12-13    10
# 2019-12-14    21
# 2019-12-15    29
# 2019-12-16    30
# 2019-12-17     9
# 2019-12-18    19
# 2019-12-19    11
# 2019-12-20    26
# 2019-12-21    13
# ...

# %%
df.groupby(pd.Grouper(freq='M')).mean()
# Out:
#                  hoge
# 2019-01-31  16.193548
# 2019-02-28  13.392857
# 2019-03-31  15.645161
# 2019-04-30  13.100000
# 2019-05-31  16.354839
# 2019-06-30  18.600000
# 2019-07-31  14.322581
# 2019-08-31  16.903226
# 2019-09-30  15.133333
# 2019-10-31  15.838710
# 2019-11-30  16.066667
# 2019-12-31  15.516129

# %%
df.loc[:, 'hoge'].resample('M').mean()
# Out:
# 2019-01-31    16.193548
# 2019-02-28    13.392857
# 2019-03-31    15.645161
# 2019-04-30    13.100000
# 2019-05-31    16.354839
# 2019-06-30    18.600000
# 2019-07-31    14.322581
# 2019-08-31    16.903226
# 2019-09-30    15.133333
# 2019-10-31    15.838710
# 2019-11-30    16.066667
# 2019-12-31    15.516129
# Freq: M, Name: hoge, dtype: float64

# %%
pd.date_range(start='2019-01-01', end='2019-12-31', freq='W-SAT')
# Out:
# DatetimeIndex(['2019-01-05', '2019-01-12', '2019-01-19', '2019-01-26',
#                '2019-02-02', '2019-02-09', '2019-02-16', '2019-02-23',
#                '2019-03-02', '2019-03-09', '2019-03-16', '2019-03-23',
#                '2019-03-30', '2019-04-06', '2019-04-13', '2019-04-20',
#                '2019-04-27', '2019-05-04', '2019-05-11', '2019-05-18',
#                '2019-05-25', '2019-06-01', '2019-06-08', '2019-06-15',
#                '2019-06-22', '2019-06-29', '2019-07-06', '2019-07-13',
#                '2019-07-20', '2019-07-27', '2019-08-03', '2019-08-10',
#                '2019-08-17', '2019-08-24', '2019-08-31', '2019-09-07',
#                '2019-09-14', '2019-09-21', '2019-09-28', '2019-10-05',
#                '2019-10-12', '2019-10-19', '2019-10-26', '2019-11-02',
#                '2019-11-09', '2019-11-16', '2019-11-23', '2019-11-30',
#                '2019-12-07', '2019-12-14', '2019-12-21', '2019-12-28'],
# ...

# %%
df_year = pd.DataFrame(df.groupby(pd.Grouper(freq='W-SAT')).sum(), columns=['hoge'])
df_year
# Out:
#             hoge
# 2019-01-05   111
# 2019-01-12    75
# 2019-01-19   147
# 2019-01-26   109
# 2019-02-02    91
# 2019-02-09   106
# 2019-02-16    97
# 2019-02-23    61
# 2019-03-02   102
# 2019-03-09    46
# 2019-03-16   169
# 2019-03-23   124
# 2019-03-30   101
# 2019-04-06   107
# 2019-04-13    75
# 2019-04-20    85
# 2019-04-27   119
# 2019-05-04    92
# 2019-05-11    63
# 2019-05-18   143
# 2019-05-25   115
# 2019-06-01   134
# 2019-06-08   157
# 2019-06-15   104
# 2019-06-22   140
# 2019-06-29   136
# 2019-07-06   102
# 2019-07-13    81
# 2019-07-20   100
# 2019-07-27   129
# 2019-08-03    81
# 2019-08-10   151
# 2019-08-17    49
# 2019-08-24   142
# 2019-08-31   144
# 2019-09-07   108
# 2019-09-14    89
# 2019-09-21    97
# 2019-09-28   139
# 2019-10-05   114
# 2019-10-12   104
# 2019-10-19    97
# 2019-10-26   109
# 2019-11-02   137
# 2019-11-09   101
# 2019-11-16    84
# 2019-11-23   149
# 2019-11-30    99
# 2019-12-07    89
# 2019-12-14    99
# 2019-12-21   137
# ...

# %%
import pandas as pd

# %%
df_201705 = pd.read_csv('data/201705health.csv', encoding='utf-8', index_col='日付', parse_dates=True)
df_201705
# Out:
#                 歩数  摂取カロリー
# 日付
# 2017-05-01  1439.0  4500.0
# 2017-05-02  8120.0  2420.0
# 2017-05-03     NaN     NaN
# 2017-05-04  2329.0  1500.0
# 2017-05-05     NaN     NaN
# 2017-05-06  3233.0  1800.0
# 2017-05-07  9593.0  2200.0
# 2017-05-08  9213.0  1800.0
# 2017-05-09  5593.0  2500.0

# %%
df_201705_drop = df_201705.dropna()
df_201705_drop
# Out:
#                 歩数  摂取カロリー
# 日付
# 2017-05-01  1439.0  4500.0
# 2017-05-02  8120.0  2420.0
# 2017-05-04  2329.0  1500.0
# 2017-05-06  3233.0  1800.0
# 2017-05-07  9593.0  2200.0
# 2017-05-08  9213.0  1800.0
# 2017-05-09  5593.0  2500.0

# %%
df_201705_fillna = df_201705.fillna(0)
df_201705_fillna
# Out:
#                 歩数  摂取カロリー
# 日付
# 2017-05-01  1439.0  4500.0
# 2017-05-02  8120.0  2420.0
# 2017-05-03     0.0     0.0
# 2017-05-04  2329.0  1500.0
# 2017-05-05     0.0     0.0
# 2017-05-06  3233.0  1800.0
# 2017-05-07  9593.0  2200.0
# 2017-05-08  9213.0  1800.0
# 2017-05-09  5593.0  2500.0

# %%
df_201705_fill = df_201705.fillna(method='ffill')
df_201705_fill
# Out:
#                 歩数  摂取カロリー
# 日付
# 2017-05-01  1439.0  4500.0
# 2017-05-02  8120.0  2420.0
# 2017-05-03  8120.0  2420.0
# 2017-05-04  2329.0  1500.0
# 2017-05-05  2329.0  1500.0
# 2017-05-06  3233.0  1800.0
# 2017-05-07  9593.0  2200.0
# 2017-05-08  9213.0  1800.0
# 2017-05-09  5593.0  2500.0

# %%
df_201705_ = df_201705.fillna(df_201705.mean())
df_201705_
# Out:
#                      歩数       摂取カロリー
# 日付
# 2017-05-01  1439.000000  4500.000000
# 2017-05-02  8120.000000  2420.000000
# 2017-05-03  5645.714286  2388.571429
# 2017-05-04  2329.000000  1500.000000
# 2017-05-05  5645.714286  2388.571429
# 2017-05-06  3233.000000  1800.000000
# 2017-05-07  9593.000000  2200.000000
# 2017-05-08  9213.000000  1800.000000
# 2017-05-09  5593.000000  2500.000000

# %%
df_201705_ = df_201705.fillna(df_201705.median())
df_201705_
# Out:
#                 歩数  摂取カロリー
# 日付
# 2017-05-01  1439.0  4500.0
# 2017-05-02  8120.0  2420.0
# 2017-05-03  5593.0  2200.0
# 2017-05-04  2329.0  1500.0
# 2017-05-05  5593.0  2200.0
# 2017-05-06  3233.0  1800.0
# 2017-05-07  9593.0  2200.0
# 2017-05-08  9213.0  1800.0
# 2017-05-09  5593.0  2500.0

# %%
df_201705_ = df_201705.fillna(df_201705.mode().iloc[0,:])
df_201705_
# Out:
#                 歩数  摂取カロリー
# 日付
# 2017-05-01  1439.0  4500.0
# 2017-05-02  8120.0  2420.0
# 2017-05-03  1439.0  1800.0
# 2017-05-04  2329.0  1500.0
# 2017-05-05  1439.0  1800.0
# 2017-04-22        0       1       0
# 2017-04-23        0       1       0
# 2017-04-24        0       0       1
# 2017-04-25        0       0       1
# ...

# %%
df_merged = pd.concat([df, df_moved], axis=1)
df_merged
# Out:
#                歩数  摂取カロリー   歩数/カロリー  運動指数  運動_High  運動_Low  運動_Mid
# date
# 2017-04-01   5439  2500.0  2.175600   Low        0       1       0
# 2017-04-02   2510  2300.0  1.091304   Low        0       1       0
# 2017-04-03  10238  1950.0  5.250256   Mid        0       0       1
# 2017-04-04   8209  1850.0  4.437297   Mid        0       0       1
# 2017-04-05   9434  1930.0  4.888083   Mid        0       0       1
# 2017-04-06   7593  1800.0  4.218333   Mid        0       0       1
# 2017-04-07   9320  1940.0  4.804124   Mid        0       0       1
# 2017-04-08   4873  2300.0  2.118696   Low        0       1       0
# 2017-04-09  12045  1950.0  6.176923  High        1       0       0
# 2017-04-10   7493  1850.0  4.050270   Mid        0       0       1
# 2017-04-11   7289  1930.0  3.776684   Mid        0       0       1
# 2017-04-12   6481  2300.0  2.817826   Low        0       1       0
# 2017-04-13  10287  1800.0  5.715000   Mid        0       0       1
# ...

# %%
df_merged_0405 = pd.concat([df_merged, df_201705_fill], axis=0, sort=True)
df_merged_0405
# Out:
#             摂取カロリー       歩数   歩数/カロリー  運動_High  運動_Low  運動_Mid  運動指数
# 2017-04-01  2500.0   5439.0  2.175600      0.0     1.0     0.0   Low
# 2017-04-02  2300.0   2510.0  1.091304      0.0     1.0     0.0   Low
# 2017-04-03  1950.0  10238.0  5.250256      0.0     0.0     1.0   Mid
# 2017-04-04  1850.0   8209.0  4.437297      0.0     0.0     1.0   Mid
# 2017-04-05  1930.0   9434.0  4.888083      0.0     0.0     1.0   Mid
# 2017-04-06  1800.0   7593.0  4.218333      0.0     0.0     1.0   Mid
# 2017-04-07  1940.0   9320.0  4.804124      0.0     0.0     1.0   Mid
# 2017-04-08  2300.0   4873.0  2.118696      0.0     1.0     0.0   Low
# 2017-04-09  1950.0  12045.0  6.176923      1.0     0.0     0.0  High
# 2017-04-10  1850.0   7493.0  4.050270      0.0     0.0     1.0   Mid
# 2017-04-11  1930.0   7289.0  3.776684      0.0     0.0     1.0   Mid
# 2017-04-12  2300.0   6481.0  2.817826      0.0     1.0     0.0   Low
# 2017-04-13  1800.0  10287.0  5.715000      0.0     0.0     1.0   Mid
# ...

# %%
df = pd.read_pickle('data/df_201704health.pickle')
df
# Out:
#                歩数  摂取カロリー   歩数/カロリー  運動指数
# date
# 2017-04-01   5439  2500.0  2.175600   Low
# 2017-04-02   2510  2300.0  1.091304   Low
# 2017-04-03  10238  1950.0  5.250256   Mid
# 2017-04-04   8209  1850.0  4.437297   Mid
# 2017-04-05   9434  1930.0  4.888083   Mid
# 2017-04-06   7593  1800.0  4.218333   Mid
# 2017-04-07   9320  1940.0  4.804124   Mid
# 2017-04-08   4873  2300.0  2.118696   Low
# 2017-04-09  12045  1950.0  6.176923  High
# 2017-04-10   7493  1850.0  4.050270   Mid
# 2017-04-11   7289  1930.0  3.776684   Mid
# 2017-04-12   6481  2300.0  2.817826   Low
# 2017-04-13  10287  1800.0  5.715000   Mid
# 2017-04-14   8043  1940.0  4.145876   Mid
# 2017-04-15   7435  2300.0  3.232609   Mid
# 2017-04-16   7529  2300.0  3.273478   Mid
# 2017-04-17   8031  1940.0  4.139691   Mid
# 2017-04-18   8475  2300.0  3.684783   Mid
# 2017-04-19   8132  1950.0  4.170256   Mid
# 2017-04-20  15328  1800.0  8.515556  High
# 2017-04-21  12849  1940.0  6.623196  High
# ...

# %%
df.loc[:, '摂取カロリー'].max()
# Out:
# 2500.0

# %%
df.loc[:, '摂取カロリー'].min()
# Out:
# 1800.0

# %%
df.loc[:, '摂取カロリー'].mode()
# Out:
# 0    2300.0
# dtype: float32

# %%
df.loc[:, '摂取カロリー'].mean()
# Out:
# 2026.6666259765625

# %%
df.loc[:, '摂取カロリー'].median()
# Out:
# 1945.0

# %%
df.loc[:, '摂取カロリー'].std()
# Out:
# 205.5494384765625

# %%
df.loc[:, '摂取カロリー'].std(ddof=0)
# Out:
# 202.09457397460938

# %%
df[df.loc[:, '摂取カロリー']==2300].count()
# Out:
# 歩数         8
# 摂取カロリー     8
# 歩数/カロリー    8
# 運動指数       8
# dtype: int64

# %%
df.describe()
# Out:
#                  歩数       摂取カロリー    歩数/カロリー
# count     30.000000    30.000000  30.000000
# mean    7766.366667  2026.666626   3.929658
# std     2689.269308   205.549438   1.563674
# min     2510.000000  1800.000000   1.091304
# 25%     6661.500000  1870.000000   2.921522
# 50%     7561.000000  1945.000000   4.030762
# 75%     8408.500000  2300.000000   4.421622
# max    15328.000000  2500.000000   8.515556

# %%
df.corr()
# Out:
#                歩数    摂取カロリー   歩数/カロリー
# 歩数       1.000000 -0.498703  0.982828
# 摂取カロリー  -0.498703  1.000000 -0.636438
# 歩数/カロリー  0.982828 -0.636438  1.000000

# %%
# %matplotlib inline

# %%
from pandas.plotting import scatter_matrix

# %%
_ = scatter_matrix(df)
# Out:
# /Users/ishidzukahiroyuki/.pyenv/versions/anaconda3-2019.07/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 27497 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ishidzukahiroyuki/.pyenv/versions/anaconda3-2019.07/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/ishidzukahiroyuki/.pyenv/versions/anaconda3-2019.07/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 27497 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/ishidzukahiroyuki/.pyenv/versions/anaconda3-2019.07/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 25968 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
df.loc[:, ['歩数', '摂取カロリー']]
# Out:
#                歩数  摂取カロリー
# date
# 2017-04-01   5439  2500.0
# 2017-04-02   2510  2300.0
# 2017-04-03  10238  1950.0
# 2017-04-04   8209  1850.0
# 2017-04-05   9434  1930.0
# 2017-04-06   7593  1800.0
# 2017-04-07   9320  1940.0
# 2017-04-08   4873  2300.0
# 2017-04-09  12045  1950.0
# 2017-04-10   7493  1850.0
# 2017-04-11   7289  1930.0
# 2017-04-12   6481  2300.0
# 2017-04-13  10287  1800.0
# 2017-04-14   8043  1940.0
# 2017-04-15   7435  2300.0
# 2017-04-16   7529  2300.0
# 2017-04-17   8031  1940.0
# 2017-04-18   8475  2300.0
# 2017-04-19   8132  1950.0
# 2017-04-20  15328  1800.0
# 2017-04-21  12849  1940.0
# 2017-04-22   4029  2300.0
# 2017-04-23   3890  1950.0
# 2017-04-24   8093  1850.0
# 2017-04-25   7823  1950.0
# 2017-04-26   7492  1850.0
# 2017-04-27   7203  1930.0
# 2017-04-28   7302  1850.0
# 2017-04-29   6033  2300.0
# 2017-04-30   4093  1950.0

# %%
df.loc[:, ['歩数', '摂取カロリー']].values
# Out:
# array([[ 5439.,  2500.],
#        [ 2510.,  2300.],
#        [10238.,  1950.],
#        [ 8209.,  1850.],
#        [ 9434.,  1930.],
#        [ 7593.,  1800.],
#        [ 9320.,  1940.],
#        [ 4873.,  2300.],
#        [12045.,  1950.],
#        [ 7493.,  1850.],
#        [ 7289.,  1930.],
#        [ 6481.,  2300.],
#        [10287.,  1800.],
#        [ 8043.,  1940.],
#        [ 7435.,  2300.],
#        [ 7529.,  2300.],
#        [ 8031.,  1940.],
#        [ 8475.,  2300.],
#        [ 8132.,  1950.],
#        [15328.,  1800.],
#        [12849.,  1940.],
#        [ 4029.,  2300.],
#        [ 3890.,  1950.],
#        [ 8093.,  1850.],
#        [ 7823.,  1950.],
#        [ 7492.,  1850.],
#        [ 7203.,  1930.],
#        [ 7302.,  1850.],
#        [ 6033.,  2300.],
#        [ 4093.,  1950.]])

# %%
a = np.arange(3)
b = np.arange(-3, 3).reshape(2,3)
c = np.arange(1,7).reshape(2,3)
d = np.arange(6).reshape(3,2)
e = np.linspace(-1, 1, 10)
print("a:",a)
print("b:",b)
print("c:",c)
print("d:",d)
print("e:",e)
# Out:
# a: [0 1 2]
# b: [[-3 -2 -1]
#  [ 0  1  2]]
# c: [[1 2 3]
#  [4 5 6]]
# d: [[0 1]
#  [2 3]
#  [4 5]]
# e: [-1.         -0.77777778 -0.55555556 -0.33333333 -0.11111111  0.11111111
#   0.33333333  0.55555556  0.77777778  1.        ]

# %%
a.shape
b.shape
c.shape
d.shape
e.shape
# Out:
# (10,)

# %%
li = [[-3,-2,-1],[0,1,2]]
new = []
for i, j in enumerate(li):
    new.append([])
    for k in j:
        new[i].append(abs(k))
print(new)
# Out:
# [[3, 2, 1], [0, 1, 2]]

# %%
np.abs(b)
# Out:
# array([[3, 2, 1],
#        [0, 1, 2]])

# %%
b
# Out:
# array([[-3, -2, -1],
#        [ 0,  1,  2]])

# %%
np.sin(e)
# Out:
# array([-0.84147098, -0.70169788, -0.52741539, -0.3271947 , -0.11088263,
#         0.11088263,  0.3271947 ,  0.52741539,  0.70169788,  0.84147098])

# %%
np.cos(e)
# Out:
# array([0.54030231, 0.71247462, 0.84960756, 0.94495695, 0.99383351,
#        0.99383351, 0.94495695, 0.84960756, 0.71247462, 0.54030231])

# %%
np.log(a)
# Out:
# /Users/ishidzukahiroyuki/.pyenv/versions/anaconda3-2019.07/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.
# array([      -inf, 0.        , 0.69314718])

# %%
np.log10(c)
# Out:
# array([[0.        , 0.30103   , 0.47712125],
#        [0.60205999, 0.69897   , 0.77815125]])

# %%
np.exp(e)
# Out:
# array([0.36787944, 0.45942582, 0.57375342, 0.71653131, 0.89483932,
#        1.11751907, 1.39561243, 1.742909  , 2.17662993, 2.71828183])

# %%
np.exp(a)
# Out:
# array([1.        , 2.71828183, 7.3890561 ])

# %%
a
# Out:
# array([0, 1, 2])

# %%
a + 10
# Out:
# array([10, 11, 12])

# %%
b
# Out:
# array([[-3, -2, -1],
#        [ 0,  1,  2]])

# %%
a + b
# Out:
# array([[-3, -1,  1],
#        [ 0,  2,  4]])

# %%
a1 = a[:, np.newaxis]
a1
# Out:
# array([[0],
#        [1],
#        [2]])

# %%
a[np.newaxis,:]
# Out:
# array([[0, 1, 2]])

# %%
a + a1
# Out:
# array([[0, 1, 2],
#        [1, 2, 3],
#        [2, 3, 4]])

# %%
c
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
c - np.mean(c)
# Out:
# array([[-2.5, -1.5, -0.5],
#        [ 0.5,  1.5,  2.5]])

# %%
b
# Out:
# array([[-3, -2, -1],
#        [ 0,  1,  2]])

# %%
b * 2
# Out:
# array([[-6, -4, -2],
#        [ 0,  2,  4]])

# %%
b**3
# Out:
# array([[-27,  -8,  -1],
#        [  0,   1,   8]])

# %%
b - a
# Out:
# array([[-3, -3, -3],
#        [ 0,  0,  0]])

# %%
a * b
# Out:
# array([[ 0, -2, -2],
#        [ 0,  1,  4]])

# %%
a / c
# Out:
# array([[0.        , 0.5       , 0.66666667],
#        [0.        , 0.2       , 0.33333333]])

# %%
c /a
# Out:
# /Users/ishidzukahiroyuki/.pyenv/versions/anaconda3-2019.07/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.
# array([[inf, 2. , 1.5],
#        [inf, 5. , 3. ]])

# %%
c / (a+1e-6)
# Out:
# array([[1.00000000e+06, 1.99999800e+00, 1.49999925e+00],
#        [4.00000000e+06, 4.99999500e+00, 2.99999850e+00]])

# %%
np.dot(b ,a)
# Out:
# array([-4,  5])

# %%
b@a
# Out:
# array([-4,  5])

# %%
b @ d
# Out:
# array([[ -8, -14],
#        [ 10,  13]])

# %%
d @ b
# Out:
# array([[  0,   1,   2],
#        [ -6,  -1,   4],
#        [-12,  -3,   6]])

# %%
a > 1
# Out:
# array([False, False,  True])

# %%
b > 0
# Out:
# array([[False, False, False],
#        [False,  True,  True]])

# %%
np.count_nonzero(b > 0)
# Out:
# 2

# %%
np.sum(b > 0)
# Out:
# 2

# %%
np.any(b > 0)
# Out:
# True

# %%
np.all(b > 0)
# Out:
# False

# %%
b[b > 0]
# Out:
# array([1, 2])

# %%
b
# Out:
# array([[-3, -2, -1],
#        [ 0,  1,  2]])

# %%
b == c
# Out:
# array([[False, False, False],
#        [False, False, False]])

# %%
a == b
# Out:
# array([[False, False, False],
#        [ True,  True,  True]])

# %%
(b == c) | (a == b)
# Out:
# array([[False, False, False],
#        [ True,  True,  True]])

# %%
b[(b == c)|(a == b)]
# Out:
# array([0, 1, 2])

# %%
np.allclose(b, c)
# Out:
# False

# %%
np.allclose(b, c, atol=10)
# Out:
# True

# %%
np.sum(a)
# Out:
# 3

# %%
a.sum()
# Out:
# 3
